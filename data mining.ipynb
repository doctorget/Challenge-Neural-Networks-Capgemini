# %%
import os 
import pandas as pd
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.

# %%
dicionario = {'label':[],'path':[]}

# %%
for file in os.listdir('data-train'): 
    contador = 0 
    for i in os.listdir('data-train/'+file): 
        if len(os.listdir('data-train/'+file)) <= 20: 
            geraImg = ImageDataGenerator(rescale = 1./255, rotation_range = 7, horizontal_flip = True, shear_range = 0.2, height_shift_range = 0.07, zoom_range = 0.2) 
            base_teste = geraImg.flow_from_directory('data-train/'+file, target_size = (64, 64), batch_size = 32, class_mode = 'binary')
# Out:
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# Found 0 images belonging to 0 classes.
# ...

# %%
for file in os.listdir('data-train'):
    contador = 0
    for i in os.listdir('data-train/'+file):
        if len(os.listdir('data-train/'+file)) <= 20:
            for j in os.listdir('data-train/'+file):
                   dicionario2['label'].append(file)
                   dicionario2['path'].append("data-train/{0}/{1}".format(file,i))
                    
            break
        else:
            for j in os.listdir('data-train/'+file):
                if contador > 30:
                    break
                dicionario['label'].append(file)
                dicionario['path'].append("data-train/{0}/{1}".format(file,j))
                contador += 1

# %%
for i in os.listdir('data-train/-1')
== '-1'
# Out:
# False

# %%
df2 = pd.DataFrame(dicionario2)

# %%
len(os.listdir('data-train/-1'))
# Out:
# 577

# %%
len(df[df['label'] == '448'])
# Out:
# 1

# %%
df2 = df2.drop_duplicates()
len(df2)
# Out:
# 2230

# %%
df = df.drop_duplicates()

# %%
df = df.reset_index()

# %%
len(df)
# Out:
# 131

# %%
df.drop('index',axis=1,inplace=True)

# %%
df.head()
# Out:
#   label                                   path
# 0    -1  data-train/-1/PM-WWA-20050416-037.jpg
# 1    -1  data-train/-1/PM-WWA-20050513-229.jpg
# 2    -1  data-train/-1/PM-WWA-20050513-243.jpg
# 3    -1  data-train/-1/PM-WWA-20050520-134.jpg
# 4    -1  data-train/-1/PM-WWA-20050612-047.jpg

# %%
df.to_csv("dataset_train30.csv",index=False)

# %%
df.head()
# Out:
#   label                                   path
# 0    -1  data-train/-1/PM-WWA-20050416-037.jpg
# 1    -1  data-train/-1/PM-WWA-20050513-229.jpg
# 2    -1  data-train/-1/PM-WWA-20050513-243.jpg
# 3    -1  data-train/-1/PM-WWA-20050520-134.jpg
# 4    -1  data-train/-1/PM-WWA-20050612-047.jpg

# %%
df.label.value_counts()
# Out:
# -1      577
# 2352     37
# 1543     24
# 2529     23
# 2628     22
#        ...
# 3763      1
# 3560      1
# 5691      1
# 3437      1
# 5212      1
# Name: label, Length: 2235, dtype: int64

# %%
df[(df['label'] == '2352') | (df['label'] == '1543') | (df['label'] == '2529') | (df['label'] == '2628') | (df['label'] == '1333') | (df['label'] == '2556') | (df['label'] == '1746') | (df['label'] == '2907') | (df['label'] == '2579') | (df['label'] == '3101')]
# Out:
#      label                                        path
# 674   1333     data-train/1333/PM-WWA-20050620-050.jpg
# 675   1333     data-train/1333/PM-WWA-20050620-153.jpg
# 676   1333     data-train/1333/PM-WWA-20070526-232.jpg
# 677   1333     data-train/1333/PM-WWA-20070617-087.jpg
# 678   1333     data-train/1333/PM-WWA-20070620-023.jpg
# ...    ...                                         ...
# 2015  3101    data-train/3101/PM-WWA-20060613-A072.jpg
# 2016  3101    data-train/3101/PM-WWA-20060613-A090.jpg
# 2017  3101     data-train/3101/PM-WWA-20060618-003.jpg
# 2018  3101  data-train/3101/PM-WWA-20060618-051-01.tif
# 2019  3101     data-train/3101/PM-WWA-20060618-059.jpg
#
# [207 rows x 2 columns]

# %%
df[(df['label'] == '2352') | (df['label'] == '1543')]
# Out:
#     label                                      path
# 730  1543   data-train/1543/PM-WWA-20050612-045.jpg
# 731  1543   data-train/1543/PM-WWA-20050831-075.jpg
# 732  1543   data-train/1543/PM-WWA-20050907-003.jpg
# 733  1543   data-train/1543/PM-WWA-20060530-126.jpg
# 734  1543  data-train/1543/PM-WWA-20060530-C011.jpg
# ..    ...                                       ...
# 995  2352   data-train/2352/PM-WWA-20130829-149.jpg
# 996  2352   data-train/2352/PM-WWA-20140625-002.jpg
# 997  2352   data-train/2352/PM-WWA-20140712-198.jpg
# 998  2352   data-train/2352/PM-WWA-20150823-036.jpg
# 999  2352   data-train/2352/PM-WWA-20160811-113.jpg
#
# [61 rows x 2 columns]
